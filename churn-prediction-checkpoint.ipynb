# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Telco_customer_churn.csv")
print("shape fo the data ",df.shape)
print("columns of the data ",df.columns)
print("sata types ",df.dtypes)
print("null values ",df.isnull().sum())
print(df["Churn Label"].value_counts())
# Out:
# shape fo the data  (7043, 33)
# columns of the data  Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')
# sata types  CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# Churn Reason          object
# dtype: object
# null values  CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Total Charges"].dtypes
# Out:
# dtype('O')

# %%
df["Total Charges"]=pd.to_numeric(df["Total Charges"],errors="coerce")

# %%
df["Total Charges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df["Total Charges"]=df["Total Charges"].fillna(df["Total Charges"].median())

# %%
df["Total Charges"].median()
# Out:
# np.float64(1397.475)

# %%
drop_columns=["CustomerID","Country","State","City","Lat Long","Latitude","Longitude","Zip Code","Churn Score","Churn Label","Churn Reason","Count"]

# %%
model_df=df.drop(columns=drop_columns)

# %%
model_df.head(2)
# Out:
#    Gender Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0    Male             No      No         No              2           Yes
# 1  Female             No      No        Yes              2           Yes
#
#   Multiple Lines Internet Service Online Security Online Backup  ...  \
# 0             No              DSL             Yes           Yes  ...
# 1             No      Fiber optic              No            No  ...
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# 1           No           No               No  Month-to-month
#
#   Paperless Billing    Payment Method Monthly Charges  Total Charges  \
# 0               Yes      Mailed check           53.85         108.15
# 1               Yes  Electronic check           70.70         151.65
#
#    Churn Value  CLTV
# 0            1  3239
# 1            1  2701
#
# [2 rows x 21 columns]

# %%
model_df["Avg_monthSpend"]=model_df["Total Charges"]/model_df["Tenure Months"]+1

# %%
model_df["Num Service"] =( model_df["Phone Service"].apply(lambda x: 1 if x == "Yes" else 0)+ 
model_df["Multiple Lines"].apply(lambda x: 1 if x=="Yes" else 0)+
model_df["Online Security"].apply(lambda x : 1 if x=="Yes" else 0)+
model_df["Online Backup"].apply(lambda x: 1 if x=="Yes" else 0)+
model_df["Device Protection"].apply(lambda x: 1 if x=="Yes" else 0)+
model_df["Tech Support"].apply(lambda x :1 if x=="Yes" else 0)+
model_df["Streaming TV"].apply(lambda x:1 if x =="Yes" else 0)+
model_df["Streaming Movies"].apply(lambda x: 1 if x=="Yes" else 0))

# %%
print(model_df["Num Service"].value_counts().sort_index())
# Out:
# Num Service
# 0      80
# 1    1701
# 2    1188
# 3     965
# 4     922
# 5     908
# 6     676
# 7     395
# 8     208
# Name: count, dtype: int64

# %%
model_df["Is Month to Month"]=model_df["Contract"].apply(lambda x: 1 if x =="Month-to-month"else 0 )
model_df["Fiber"]=model_df["Internet Service"].apply(lambda x: 1 if x =="Fiber optic" else 0)

# %%
print(model_df["Is Month to Month"].value_counts())
print(model_df["Fiber"].value_counts())
# Out:
# Is Month to Month
# 1    3875
# 0    3168
# Name: count, dtype: int64
# Fiber
# 0    3947
# 1    3096
# Name: count, dtype: int64

# %%
model_df.select_dtypes(include="string").columns
# Out:
# Index([], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
for col in model_df.select_dtypes(include="string").columns:
    model_df[col]=encoder.fit_transform(model_df[col])

# %%
x=model_df.drop(["Churn Value"],axis =1)
y=model_df["Churn Value"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train, y_test=train_test_split(x,y,test_size=0.2 ,stratify=y,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (5634, 24)
# (1409, 24)

# %%
print(x_train.isnull().sum()[x_train.isnull().sum() > 0])
# Out:
# Series([], dtype: int64)

# %%
import numpy as np
x_train=x_train.replace([np.inf,-np.inf], np.nan)
x_test=x_test.replace([np.inf,-np.inf],np.nan)
x_train.fillna(x_train.median())
x_test.fillna(x_test.median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       2 x_train=x_train.replace([np.inf,-np.inf], np.nan)
#       3 x_test=x_test.replace([np.inf,-np.inf],np.nan)
# ----> 4 x_train.fillna(x_train.median())
#       5 x_test.fillna(x_test.median())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11733, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11725 @doc(make_doc("median", ndim=2))
#   11726 def median(
#   11727     self,
#    (...)  11731     **kwargs,
#   11732 ):
# > 11733     result = super().median(axis, skipna, numeric_only, **kwargs)
#   11734     if isinstance(result, Series):
#   11735         result = result.__finalize__(self, method="median")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12496, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12489 def median(
#   12490     self,
#   12491     axis: Axis | None = 0,
#    (...)  12494     **kwargs,
#   12495 ) -> Series | float:
# > 12496     return self._stat_function(
#   12497         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12498     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     785     inferred = lib.infer_dtype(values)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#     789     values = values.astype("f8")
#
# TypeError: Cannot convert [['Male' 'Male' 'Male' ... 'Female' 'Female' 'Male']
#  ['No' 'No' 'No' ... 'Yes' 'No' 'No']
#  ['No' 'Yes' 'Yes' ... 'No' 'Yes' 'No']
#  ...
#  ['Month-to-month' 'Month-to-month' 'Two year' ... 'Month-to-month'
#   'One year' 'Month-to-month']
#  ['No' 'No' 'No' ... 'Yes' 'No' 'No']
#  ['Electronic check' 'Mailed check' 'Mailed check' ... 'Mailed check'
#   'Credit card (automatic)' 'Mailed check']] to numeric

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)

# %%
y_pred=rf.predict(x_test)

# %%
y_pred

# %%
from sklearn.metrics import classification_report

# %%
cr=classification_report(y_test,y_pred)

# %%
cr

# %%
y_prob=rf.predict_proba(x_test)[:,1]

# %%
x_train.dtypes
